# %%
import pandas as pd
import numpy as np
import datetime

# %%
# !pip install Openpyxl

# %%
crime=pd.read_excel('D:/Chicago_crime-analyzer/Crime_Data.xlsx')
display(crime)
# Out:
#               ID Case Number                Date                      Block  \
# 0        5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE
# 1          25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE
# 2          26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD
# 3       13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST
# 4       13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# ...          ...         ...                 ...                        ...
# 549994   1715153     G516233 2001-08-27 23:00:00       036XX S LAKE PARK AV
# 549995   1799889     G625392 2001-10-16 16:30:00         065XX S STEWART AV
# 549996   1769834     G583569 2001-09-29 05:35:00    031XX N CENTRAL PARK AV
# 549997   1788327     G610965 2001-09-12 09:05:00          065XX S CICERO AV
# 549998   1810693     G627247 2001-10-18 17:34:00       053XX W FERDINAND ST
#
#         IUCR         Primary Type  \
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  datetime64[ns]
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
crime.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1673
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
crime.dropna(subset=['Location'],inplace=True)
crime.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1103
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    334389
# Community Area          333063
# FBI Code                     0
# X Coordinate                 0
# Y Coordinate                 0
# Year                         0
# Updated On                   0
# Latitude                     0
# Longitude                    0
# Location                     0
# dtype: int64

# %%
crime.drop('Ward',axis=1,inplace=True)
crime.drop('Community Area',axis=1,inplace=True)
crime.dropna(subset=['Location Description'],inplace=True)
crime.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
crime.isnull().sum()
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541984 entries, 1 to 549998
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    541984 non-null  int64
#  1   Case Number           541984 non-null  object
#  2   Date                  541984 non-null  datetime64[ns]
#  3   Block                 541984 non-null  object
#  4   IUCR                  541984 non-null  object
#  5   Primary Type          541984 non-null  object
#  6   Description           541984 non-null  object
#  7   Location Description  541984 non-null  object
#  8   Arrest                541984 non-null  bool
#  9   Domestic              541984 non-null  bool
#  10  Beat                  541984 non-null  int64
#  11  District              541984 non-null  int64
#  12  FBI Code              541984 non-null  object
#  13  X Coordinate          541984 non-null  float64
# ...

# %%
crime.to_csv('crime_cleaned.csv',index=False)

# %%
crime.head(5)
# Out:
#          ID Case Number                Date                      Block  IUCR  \
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE   110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD   110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST   620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE   454
# 6  13203321    JG415333 2023-09-06 17:00:00           002XX N Wells st  1320
#
#       Primary Type                                        Description  \
# 1         HOMICIDE                                FIRST DEGREE MURDER
# 2         HOMICIDE                                FIRST DEGREE MURDER
# 3         BURGLARY                                     UNLAWFUL ENTRY
# 4          BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 6  CRIMINAL DAMAGE                                         TO VEHICLE
#
#                      Location Description  Arrest  Domestic  Beat  District  \
# ...

# %%
crime[(crime['Arrest'] == True) & (crime['District'] == 25)]
# Out:
#               ID Case Number                Date                   Block  \
# 1          25953    JE240540 2021-05-24 15:06:00     020XX N LARAMIE AVE
# 50      13181797    JG389859 2023-08-20 04:30:00  020XX N LEAMINGTON AVE
# 51      13181885    JG389920 2023-08-20 06:00:00    020XX N LECLAIRE AVE
# 53      13183567    JG392073 2023-08-21 14:37:00  022XX N LEAMINGTON AVE
# 57      13188630    JG398002 2023-08-26 02:15:00   047XX W FULLERTON AVE
# ...          ...         ...                 ...                     ...
# 549664   1664093     G443082 2001-07-27 20:59:00      050XX W CONCORD PL
# 549839   1658128     G440658 2001-07-26 19:24:26     027XX N LAWNDALE AV
# 549841   1828364     G661316 2001-11-02 21:27:17      017XX N KOSTNER AV
# 549867   1807474     G634809 2001-10-22 09:00:00      015XX N CENTRAL AV
# 549870   1764699     G575884 2001-09-24 15:00:00        055XX W GRAND AV
#
#         IUCR        Primary Type                       Description  \
# ...

# %%
crime.groupby('Primary Type').size().sort_values(ascending=False)
# Out:
# Primary Type
# THEFT                                111499
# BATTERY                              100473
# CRIMINAL DAMAGE                       59907
# ASSAULT                               39863
# NARCOTICS                             39147
# MOTOR VEHICLE THEFT                   36967
# OTHER OFFENSE                         33574
# BURGLARY                              23268
# DECEPTIVE PRACTICE                    21084
# ROBBERY                               20943
# HOMICIDE                              13150
# CRIMINAL TRESPASS                     12784
# WEAPONS VIOLATION                      8636
# PROSTITUTION                           4297
# OFFENSE INVOLVING CHILDREN             2997
# SEX OFFENSE                            2581
# PUBLIC PEACE VIOLATION                 2575
# CRIMINAL SEXUAL ASSAULT                1405
# LIQUOR LAW VIOLATION                   1321
# CRIM SEXUAL ASSAULT                    1163
# ARSON                                  1151
# ...

# %%
crime['Year'] = pd.to_datetime(crime['Date']).dt.year
crime[crime['Year'] == 2020]
# Out:
#               ID Case Number                Date                   Block  \
# 25      12218064    JD426642 2020-10-30 16:30:00         011XX E 82ND ST
# 2544    12112801    JD302207 2020-07-18 22:00:00     067XX N WESTERN AVE
# 3357    12012998    JD190121 2020-03-19 05:50:00    058XX W WAVELAND AVE
# 4852    12284799    JE124215 2020-06-01 09:00:00  063XX S CALIFORNIA AVE
# 4877       25667    JD457527 2020-12-13 00:37:00      015XX S SAWYER AVE
# ...          ...         ...                 ...                     ...
# 340353     25695    JD472972 2020-12-29 19:24:00     055XX W CHICAGO AVE
# 340476     25397    JD332746 2020-08-18 01:55:00         040XX W 18TH ST
# 340507     25596    JD422410 2020-11-06 02:22:00     068XX S WOLCOTT AVE
# 340652     25460    JD365391 2020-09-12 23:18:00        005XX N PINE AVE
# 340771     25011    JD202893 2020-04-05 23:18:00      000XX S WHIPPLE ST
#
#         IUCR             Primary Type                 Description  \
# ...

# %%
crime.sort_values(by='Date', ascending=True).head(10)
# Out:
#              ID Case Number       Date                 Block  IUCR  \
# 436505  1651806     G437744 2001-01-01   031XX N SEMINARY AV   841
# 255708  1312179     G000960 2001-01-01  048XX W VAN BUREN ST  1310
# 513682  1818198     G650095 2001-01-01    043XX N KENMORE AV   840
# 319049  1316070     G007383 2001-01-01         041XX W 24 PL  2820
# 270367  1353509     G057402 2001-01-01      034XX W ADAMS ST  1150
# 370088  1612702     G387812 2001-01-01     062XX S HONORE ST   840
# 248363  1370284     G074254 2001-01-01      003XX N MASON AV   820
# 250003  1312153     G001591 2001-01-01      003XX N LOREL AV  1310
# 338626  1413854     G129824 2001-01-01     051XX S KEDZIE AV   820
# 480501  1780042     G600951 2001-01-01    105XX S PARNELL AV  2825
#
#               Primary Type                     Description  \
# 436505               THEFT  FINANCIAL ID THEFT:$300 &UNDER
# 255708     CRIMINAL DAMAGE                     TO PROPERTY
# ...

# %%
crime[(crime['Arrest'] == True) & (crime['Domestic'] == True)]
# Out:
#               ID Case Number                Date                   Block  \
# 25      12218064    JD426642 2020-10-30 16:30:00         011XX E 82ND ST
# 38      12990873    JG161829 2019-08-17 13:14:00      008XX N KARLOV AVE
# 47      13176001    JG382803 2023-02-01 14:00:00    058XX S MICHIGAN AVE
# 50      13181797    JG389859 2023-08-20 04:30:00  020XX N LEAMINGTON AVE
# 51      13181885    JG389920 2023-08-20 06:00:00    020XX N LECLAIRE AVE
# ...          ...         ...                 ...                     ...
# 549881   1729812     G534500 2001-09-06 17:20:00    054XX S HERMITAGE AV
# 549884   1805046     G632404 2001-10-20 23:15:00    065XX S HERMITAGE AV
# 549934   1731775     G538899 2001-09-08 14:30:00    061XX S FRANCISCO AV
# 549948   1819164     G642135 2001-10-25 12:52:42     058XX S MICHIGAN AV
# 549984   1732967     G539954 2001-09-09 00:09:19           017XX W 16 ST
#
#         IUCR                Primary Type  \
# 25       266     CRIMINAL SEXUAL ASSAULT
# ...

# %%
crime[crime['Location Description'].isin(['SIDEWALK', 'ALLEY'])]
# Out:
#               ID Case Number                Date                     Block  \
# 101     13274437    JG500138 2023-11-10 16:30:00  047XX W BELLE PLAINE AVE
# 129     13201867    JG413796 2023-09-06 15:10:00        069XX S VERNON AVE
# 133     13208459    JG421333 2023-09-05 08:00:00       040XX W DIVISION ST
# 148     13202268    JG414251 2023-09-06 21:55:00          001XX E 114TH PL
# 193     13201805    JG413678 2023-09-06 14:45:00       031XX W FILLMORE ST
# ...          ...         ...                 ...                       ...
# 549957   1766921     G581640 2001-09-28 07:00:00         071XX S KEDZIE AV
# 549979   1811588     G641073 2001-10-24 20:32:19      120XX S WENTWORTH AV
# 549982   1791898     G614307 2001-10-12 22:05:44             011XX W 83 ST
# 549987   1662830     G451853 2001-07-31 19:21:16             021XX W 18 PL
# 549998   1810693     G627247 2001-10-18 17:34:00      053XX W FERDINAND ST
#
#         IUCR                      Primary Type  \
# ...

# %%
no_arrest_crime = crime[crime['Arrest'] == False]
no_arrest_crime[['Primary Type']]
# Out:
#                    Primary Type
# 3                      BURGLARY
# 6               CRIMINAL DAMAGE
# 7            DECEPTIVE PRACTICE
# 8       CRIMINAL SEXUAL ASSAULT
# 9                         THEFT
# ...                         ...
# 549991      MOTOR VEHICLE THEFT
# 549992       DECEPTIVE PRACTICE
# 549994            OTHER OFFENSE
# 549995                 BURGLARY
# 549996                  BATTERY
#
# [412319 rows x 1 columns]

# %%
crime.groupby('District').size().sort_values(ascending=False)
# Out:
# District
# 8     35503
# 2     34791
# 11    30344
# 25    30085
# 6     29819
# 12    29519
# 4     28865
# 3     27498
# 7     27116
# 19    26276
# 9     26049
# 18    25421
# 14    23083
# 5     22458
# 10    22427
# 1     20977
# 15    20970
# 16    18381
# 24    18209
# 22    16550
# 17    16361
# 20    11270
# 31       12
# dtype: int64

# %%
visualization_data = crime[['Primary Type', 'Year', 'Arrest']]
visualization_data
# Out:
#                Primary Type  Year  Arrest
# 1                  HOMICIDE  2021    True
# 2                  HOMICIDE  2021    True
# 3                  BURGLARY  2023   False
# 4                   BATTERY  2023    True
# 6           CRIMINAL DAMAGE  2023   False
# ...                     ...   ...     ...
# 549994        OTHER OFFENSE  2001   False
# 549995             BURGLARY  2001   False
# 549996              BATTERY  2001   False
# 549997  MOTOR VEHICLE THEFT  2001    True
# 549998            NARCOTICS  2001    True
#
# [541984 rows x 3 columns]
